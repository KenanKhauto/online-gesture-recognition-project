# %%
# %matplotlib inline

import torch
import numpy as np

from main import main, create_parser

seed = 42
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True

parser = create_parser()
args = parser.parse_args(args=[
    "--classes", "2",
    "--train-samples", "100" ,
    "--test-samples", "10",
    "--epochs", "25",
    "--uncertainty-loss", "ce",
    "grid-search-uncertainty-thresh", "--range", "0.1", "1.", "0.1"
])
main(args);
# Out:
# Uncertainty threshold: 0.10000000149011612
# Use CUDA: True
# Use MPS: True
# Files already downloaded and verified
#   0%|          | 0/25 [00:00<?, ?it/s]
# Output()
# Total Runtime: 02:49 (00:04 per Epoch for 25 Epochs)
# Uncertainty threshold: 0.20000000298023224
# Use CUDA: True
# Use MPS: True
# Files already downloaded and verified
#   0%|          | 0/25 [00:00<?, ?it/s]
# Output()
# Total Runtime: 01:53 (00:04 per Epoch for 25 Epochs)
# Uncertainty threshold: 0.30000001192092896
# Use CUDA: True
# Use MPS: True
# Files already downloaded and verified
#   0%|          | 0/25 [00:00<?, ?it/s]
# Output()
# Total Runtime: 01:53 (00:04 per Epoch for 25 Epochs)
# Uncertainty threshold: 0.4000000059604645
# Use CUDA: True
# Use MPS: True
# Files already downloaded and verified
#   0%|          | 0/25 [00:00<?, ?it/s]
# Output()
# Total Runtime: 02:01 (00:04 per Epoch for 25 Epochs)
# Uncertainty threshold: 0.5
# Use CUDA: True
# Use MPS: True
# Files already downloaded and verified
#   0%|          | 0/25 [00:00<?, ?it/s]
# Output()
# Total Runtime: 02:00 (00:04 per Epoch for 25 Epochs)
# Uncertainty threshold: 0.6000000238418579
# Use CUDA: True
# Use MPS: True
# Files already downloaded and verified
#   0%|          | 0/25 [00:00<?, ?it/s]
# Output()
# Total Runtime: 02:06 (00:05 per Epoch for 25 Epochs)
# Uncertainty threshold: 0.699999988079071
# Use CUDA: True
# Use MPS: True
# Files already downloaded and verified
#   0%|          | 0/25 [00:00<?, ?it/s]
# Output()
# Total Runtime: 02:12 (00:05 per Epoch for 25 Epochs)
# Uncertainty threshold: 0.800000011920929
# Use CUDA: True
# Use MPS: True
# Files already downloaded and verified
#   0%|          | 0/25 [00:00<?, ?it/s]
# Output()
# Total Runtime: 02:08 (00:04 per Epoch for 25 Epochs)
# Uncertainty threshold: 0.8999999761581421
# Use CUDA: True
# Use MPS: True
# Files already downloaded and verified
#   0%|          | 0/25 [00:00<?, ?it/s]
# Output()
# Total Runtime: 01:59 (00:04 per Epoch for 25 Epochs)
# Uncertainty threshold: 1.0
# Use CUDA: True
# Use MPS: True
# Files already downloaded and verified
#   0%|          | 0/25 [00:00<?, ?it/s]
# Output()
# Total Runtime: 02:07 (00:04 per Epoch for 25 Epochs)
