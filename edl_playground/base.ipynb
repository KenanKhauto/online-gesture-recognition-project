# %%
# %matplotlib inline

import torch
import numpy as np

from main import main, create_parser

seed = 42
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True

parser = create_parser()
args = parser.parse_args(args=[
    "--classes", "2",
    "--train-samples", "100" ,
    "--test-samples", "10",
    "--epochs", "25",
    "--no-uncertainty"
])
main(args);
# Out:
# Use CUDA: True
# Use MPS: True
# Files already downloaded and verified
#   0%|          | 0/25 [00:00<?, ?it/s]
# Output()
# Total Runtime: 01:28 (00:03 per Epoch for 25 Epochs)
